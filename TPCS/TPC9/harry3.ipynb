# %% [markdown]
# Limpar dados

# %%
import re
import spacy

nlp = spacy.load("pt_core_news_sm")

f = open("Harry Potter e A Pedra Filosofal.txt", "r", encoding="utf8") 
texto = f.read()

texto = re.sub(r'\f', '', texto)

doc = nlp(texto)
livro = []
for sent in doc.sents:
    tokens = [token.text.lower() for token in sent if not token.is_punct and not token.is_space]
    if len(tokens) > 0:
        livro.append(tokens)

print(livro)
# Out:
# [['dados', 'de', 'copyright', 'sobre', 'a', 'obra'], ['a', 'presente', 'obra', 'é', 'disponibilizada', 'pela', 'equipe', 'le', 'livros', 'e', 'seus', 'diversos', 'parceiros', 'com', 'o', 'objetivo', 'de', 'oferecer', 'conteúdo', 'para', 'uso', 'parcial', 'em', 'pesquisas', 'e', 'estudos', 'acadêmicos', 'bem', 'como', 'o', 'simples', 'teste', 'da', 'qualidade', 'da', 'obra', 'com', 'o', 'fim', 'exclusivo', 'de', 'compra', 'futura'], ['é', 'expressamente', 'proibida', 'e', 'totalmente', 'repudíavel', 'a', 'venda', 'aluguel', 'ou', 'quaisquer', 'uso', 'comercial', 'do', 'presente', 'conteúdo'], ['sobre', 'nós'], ['o', 'le', 'livros', 'e', 'seus', 'parceiros', 'disponibilizam', 'conteúdo', 'de', 'dominio', 'publico', 'e', 'propriedade', 'intelectual', 'de', 'forma', 'totalmente', 'gratuita', 'por', 'acreditar', 'que', 'o', 'conhecimento', 'e', 'a', 'educação', 'devem', 'ser', 'acessíveis', 'e', 'livres', 'a', 'toda', 'e', 'qualquer', 'pessoa'], ['você', 'pode', 'encontrar', 'mais', 'obra
# ...

# %%
import re
import spacy

nlp = spacy.load("pt_core_news_sm")

f = open("Harry_Potter_Camara_Secreta-br.txt", "r", encoding="utf8") 
texto2 = f.read()

texto2 = re.sub(r'\f', '', texto2)

doc = nlp(texto2)
livro2 = []
for sent in doc.sents:
    tokens = [token.text.lower() for token in sent if not token.is_punct and not token.is_space]
    if len(tokens) > 0:
        livro2.append(tokens)

print(livro2)
# Out:
# [['capítulo', 'um'], ['o', 'pior', 'aniversário', 'não', 'era', 'a', 'primeira', 'vez', 'que', 'irrompia', 'uma', 'discussão', 'à', 'mesa', 'do', 'café', 'da', 'manhã', 'na', 'rua', 'dos', 'alfeneiros', 'número', '4'], ['o', 'sr.', 'válter', 'dursley', 'fora', 'acordado', 'nas', 'primeiras', 'horas', 'da', 'manhã', 'por', 'um', 'pio', 'alto', 'que', 'vinha', 'do', 'quarto', 'do', 'seu', 'sobrinho', 'harry'], ['é', 'a', 'terceira', 'vez', 'esta', 'semana'], ['berrou', 'ele', 'à', 'mesa'], ['se', 'você', 'não', 'consegue', 'controlar', 'essa', 'coruja', 'teremos', 'que', 'mandá-la', 'embora', 'harry', 'tentou', 'explicar', 'mais', 'uma', 'vez'], ['ela', 'está', 'chateada'], ['está', 'acostumada', 'a', 'voar', 'ao', 'ar', 'livre'], ['se', 'eu', 'ao', 'menos', 'pudesse', 'soltá-la', 'à', 'noite'], ['eu', 'tenho', 'cara', 'de', 'idiota'], ['rosnou', 'tio', 'válter', 'um', 'pedaço', 'de', 'ovo', 'pendurado', 'na', 'bigodeira'], ['eu', 'sei', 'o', 'que', 'vai', 'acontecer', 'se', 'você', 's
# ...

# %%
final = livro + livro2

# %% [markdown]
# Treinar modelo

# %%
from gensim.models import Word2Vec

model = Word2Vec(final, vector_size=100, window=5, min_count=2, sg=0, epochs=20, workers=3)

# %%
model.wv['harry']
# Out:
# array([ 0.02233351,  0.21250227, -0.4674772 , -0.48822626, -0.9134672 ,
#        -0.93983835,  0.577508  ,  0.05922425,  0.63861346,  0.1762602 ,
#        -0.90728855, -0.20599277, -0.1670565 , -0.4041053 , -1.4800521 ,
#        -1.1699368 ,  0.6963984 ,  0.15809143, -0.7108811 , -1.390975  ,
#         0.08476323,  0.03566424,  0.52569085,  0.293084  , -0.7180536 ,
#         0.20883808, -0.25345635,  0.13231619, -1.3236246 ,  0.37320557,
#         0.8919204 , -0.7148364 ,  0.4164403 , -0.33948705, -1.9435176 ,
#         1.9922699 ,  1.0133175 ,  0.88909614,  0.02462105,  1.0469794 ,
#         0.6767501 , -0.76246595, -0.6349067 , -0.7044563 , -0.21103743,
#        -0.10707732, -0.6999375 ,  0.5519261 ,  0.5718464 ,  0.1435374 ,
#         1.2187111 ,  0.08320593,  0.33010432,  0.52902377, -0.9867871 ,
#         0.11311971,  1.4212788 , -1.4534523 ,  0.25966287, -0.7613037 ,
#         0.86485505,  0.18309008,  1.2543005 , -0.8644766 , -0.48124033,
# ...

# %%
'rony' in model.wv
# Out:
# True

# %%
model.wv.most_similar('casa')
# Out:
# [('família', 0.8120614886283875),
#  ('escola', 0.7995297908782959),
#  ('magia', 0.7883003354072571),
#  ('vida', 0.777191162109375),
#  ('cidade', 0.7613596320152283),
#  ('lufa-lufa', 0.7556087374687195),
#  ('lembrança', 0.7523291110992432),
#  ('sair', 0.7522539496421814),
#  ('seleção', 0.7518270611763),
#  ('hogwarts', 0.7411491870880127)]

# %%
print(model.wv.similarity("harry","hermione"))
print(model.wv.similarity("harry","malfoy"))
print(model.wv.similarity("harry","rony"))
print(model.wv.similarity("harry","hagrid"))
print(model.wv.similarity("harry","gryffindor"))
# Out:
# 0.66177607
# 0.35831216
# 0.57585216
# 0.62486064
# -0.13147451

# %%
pairs = [
    ('harry', 'rony'),      
    ('harry', 'voldemort'),
    ('vassoura', 'quadribol'), 
    ('varinha', 'bruxo'),    
]

for w1, w2 in pairs:
    print('%s \t %s \t %.2f' % (w1, w2, model.wv.similarity(w1, w2)))
# Out:
# harry 	 rony 	 0.58
# harry 	 voldemort 	 0.09
# vassoura 	 quadribol 	 0.17
# varinha 	 bruxo 	 -0.08

# %%
print (model.wv.doesnt_match(["harry", "ron", "hermione", "malfoy"]))

print (model.wv.doesnt_match(["gryffindor", "slytherin", "hufflepuff", "snape"]))

print (model.wv.doesnt_match(["taça", "vassoura", "quadribol", "hermione"]))
# Out:
# malfoy
# snape
# hermione

# %%
result1 = model.wv.most_similar(positive=['harry', 'sonserina'], negative=['draco'])
print(result1)

result2 = model.wv.most_similar(positive=['sonserina', 'harry'], negative=['grifinória'])
print(result2)

result3 = model.wv.most_similar(positive=['mulher', 'bruxo'], negative=['homem'])
print( result3)
# Out:
# [('grifinória', 0.7016638517379761), ('lufa-lufa', 0.6835573315620422), ('escola', 0.6612913012504578), ('magia', 0.6511198282241821), ('moderna', 0.6392561197280884), ('existência', 0.631060779094696), ('corvinal', 0.6242278814315796), ('estação', 0.6136055588722229), ('aula', 0.6132813096046448), ('quadribol', 0.611479640007019)]
# [('quirrell', 0.707308828830719), ('ele', 0.7007015347480774), ('riddle', 0.5896344780921936), ('neville', 0.5740760564804077), ('dobby', 0.5598652362823486), ('draco', 0.5568047761917114), ('hagrid', 0.53922039270401), ('dumbledore', 0.5373360514640808), ('ela', 0.5255700945854187), ('snape', 0.5255002975463867)]
# [('história', 0.8583133816719055), ('inglaterra', 0.7994662523269653), ('família', 0.798806369304657), ('lenda', 0.7840547561645508), ('irmã', 0.7828100323677063), ('opinião', 0.7746820449829102), ('vida', 0.7688259482383728), ('esperança', 0.7520773410797119), ('foto', 0.7510660290718079), ('livraria', 0.7443024516105652)]

# %%
model.wv.save_word2vec_format('model3_harry.txt', binary=False)
#http://projector.tensorflow.org/

# %%
# !python -m gensim.scripts.word2vec2tensor -i model_harry.txt -o model_harry
# Out:
# 2026-04-29 18:49:33,892 - word2vec2tensor - INFO - running c:\Users\Utilizador\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\scripts\word2vec2tensor.py -i model_harry.txt -o model_harry
# 2026-04-29 18:49:33,892 - keyedvectors - INFO - loading projection weights from model_harry.txt
# 2026-04-29 18:49:35,027 - utils - INFO - KeyedVectors lifecycle event {'msg': 'loaded (6989, 100) matrix of type float32 from model_harry.txt', 'binary': False, 'encoding': 'utf8', 'datetime': '2026-04-29T18:49:35.016404', 'gensim': '4.4.0', 'python': '3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'load_word2vec_format'}
# 2026-04-29 18:49:35,982 - word2vec2tensor - INFO - 2D tensor file saved to model_harry_tensor.tsv
# 2026-04-29 18:49:35,982 - word2vec2tensor - INFO - Tensor metadata file saved to model_harry_metadata.tsv
# ...
